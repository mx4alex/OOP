# %% [markdown]
# # Обнаружение объектов на фото
#
#  Получение датасета
# https://huggingface.co/datasets/imagenet-1k
#
#  Ожидаемый результат работы:
#
# ![1_VXZ8CamGG2Z0M0N4t0Fmng.jpeg](attachment:1_VXZ8CamGG2Z0M0N4t0Fmng.jpeg)
